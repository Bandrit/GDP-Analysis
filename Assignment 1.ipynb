# %%
# import numpy and pandas package

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data11 = pd.read_csv('Data 1a.csv') #Import the data from .csv file
data11
# Out:
#                     Items  Description Duration  Andhra Pradesh   \
# 0   GSDP - CURRENT PRICES (` in Crore)  2011-12        379402.00
# 1   GSDP - CURRENT PRICES (` in Crore)  2012-13        411404.00
# 2   GSDP - CURRENT PRICES (` in Crore)  2013-14        464272.00
# 3   GSDP - CURRENT PRICES (` in Crore)  2014-15        526468.00
# 4   GSDP - CURRENT PRICES (` in Crore)  2015-16        609934.00
# 5   GSDP - CURRENT PRICES (` in Crore)  2016-17        699307.00
# 6        (% Growth over previous year)  2012-13             8.43
# 7        (% Growth over previous year)  2013-14            12.85
# 8        (% Growth over previous year)  2014-15            13.40
# 9        (% Growth over previous year)  2015-16            15.85
# 10       (% Growth over previous year)  2016-17            14.65
#
#     Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa  \
# 0            11063.00  143175.00  247144.00     158074.00  42367.00
# ...

# %%
data11 = data11.drop(['Items  Description','West Bengal1'], axis=1) #Drop the Items Description and West Bengal1 column
data11.head()
# Out:
#   Duration  Andhra Pradesh   Arunachal Pradesh     Assam     Bihar  \
# 0  2011-12         379402.0            11063.0  143175.0  247144.0
# 1  2012-13         411404.0            12547.0  156864.0  282368.0
# 2  2013-14         464272.0            14602.0  177745.0  317101.0
# 3  2014-15         526468.0            16761.0  198098.0  373920.0
# 4  2015-16         609934.0            18784.0  224234.0  413503.0
#
#    Chhattisgarh      Goa   Gujarat   Haryana  Himachal Pradesh      ...        \
# 0      158074.0  42367.0  615606.0  297539.0           72720.0      ...
# 1      177511.0  38120.0  724495.0  347032.0           82820.0      ...
# 2      206690.0  35921.0  807623.0  400662.0           94764.0      ...
# 3      234982.0  40633.0  895027.0  437462.0          104369.0      ...
# 4      260776.0  45002.0  994316.0  485184.0               NaN      ...
#
#    Tamil Nadu  Telangana  Tripura  Uttar Pradesh  Uttarakhand  \
# ...

# %%
data11 = data11.drop(data11.index[[0,1,2,3,4,5,6,10]], axis=0) #Drop the rest of the rows which are not useful for analysis

# %%
data11.isnull().sum() #Check number of null values across columns
# Out:
# Duration                     0
# Andhra Pradesh               0
# Arunachal Pradesh            0
# Assam                        0
# Bihar                        0
# Chhattisgarh                 0
# Goa                          0
# Gujarat                      0
# Haryana                      0
# Himachal Pradesh             1
# Jammu & Kashmir              0
# Jharkhand                    0
# Karnataka                    0
# Kerala                       0
# Madhya Pradesh               0
# Maharashtra                  1
# Manipur                      1
# Meghalaya                    0
# Mizoram                      1
# Nagaland                     1
# Odisha                       0
# Punjab                       1
# Rajasthan                    1
# Sikkim                       0
# Tamil Nadu                   0
# Telangana                    0
# Tripura                      1
# Uttar Pradesh                0
# Uttarakhand                  0
# Andaman & Nicobar Islands    1
# ...

# %%
data11.isnull().sum(axis=1) #Check null values across rows
# Out:
# 7    0
# 8    0
# 9    9
# dtype: int64

# %%
round(100*(data11.isnull().sum()/len(data11.index)),2) #Percentage of null values across columns
# Out:
# Duration                      0.00
# Andhra Pradesh                0.00
# Arunachal Pradesh             0.00
# Assam                         0.00
# Bihar                         0.00
# Chhattisgarh                  0.00
# Goa                           0.00
# Gujarat                       0.00
# Haryana                       0.00
# Himachal Pradesh             33.33
# Jammu & Kashmir               0.00
# Jharkhand                     0.00
# Karnataka                     0.00
# Kerala                        0.00
# Madhya Pradesh                0.00
# Maharashtra                  33.33
# Manipur                      33.33
# Meghalaya                     0.00
# Mizoram                      33.33
# Nagaland                     33.33
# Odisha                        0.00
# Punjab                       33.33
# Rajasthan                    33.33
# Sikkim                        0.00
# Tamil Nadu                    0.00
# Telangana                     0.00
# Tripura                      33.33
# ...

# %%
#Impute null cells with mean values

# %%
data11.loc[7:9,'Tripura'] = data11.loc[7:9,'Tripura'].fillna(data11.loc[7:9,'Tripura'].mean())
data11.loc[7:9,'Himachal Pradesh'] = data11.loc[7:9,'Himachal Pradesh'].fillna(data11.loc[7:9,'Himachal Pradesh'].mean())
data11.loc[7:9,'Maharashtra'] = data11.loc[7:9,'Maharashtra'].fillna(data11.loc[7:9,'Maharashtra'].mean())
data11.loc[7:9,'Manipur'] = data11.loc[7:9,'Manipur'].fillna(data11.loc[7:9,'Manipur'].mean())
data11.loc[7:9,'Mizoram'] = data11.loc[7:9,'Mizoram'].fillna(data11.loc[7:9,'Mizoram'].mean())
data11.loc[7:9,'Nagaland'] = data11.loc[7:9,'Nagaland'].fillna(data11.loc[7:9,'Nagaland'].mean())
data11.loc[7:9,'Punjab'] = data11.loc[7:9,'Punjab'].fillna(data11.loc[7:9,'Punjab'].mean())
data11.loc[7:9,'Rajasthan'] = data11.loc[7:9,'Rajasthan'].fillna(data11.loc[7:9,'Rajasthan'].mean())
data11.loc[7:9,'Andaman & Nicobar Islands'] = data11.loc[7:9,'Andaman & Nicobar Islands'].fillna(data11.loc[7:9,'Andaman & Nicobar Islands'].mean())
data11
# Out:
#   Duration  Andhra Pradesh   Arunachal Pradesh  Assam  Bihar  Chhattisgarh  \
# 7  2013-14            12.85              16.38  13.31  12.30         16.44
# 8  2014-15            13.40              14.79  11.45  17.92         13.69
# 9  2015-16            15.85              12.07  13.19  10.59         10.98
#
#      Goa  Gujarat  Haryana  Himachal Pradesh      ...        Tamil Nadu  \
# 7  -5.77    11.47    15.45             14.42      ...             13.51
# 8  13.12    10.82     9.18             10.14      ...             12.51
# 9  10.75    11.09    10.91             12.28      ...             10.99
#
#    Telangana  Tripura  Uttar Pradesh  Uttarakhand  Andaman & Nicobar Islands  \
# 7      12.63    18.14          14.73        13.64                     16.680
# 8      13.05    15.92          10.51         8.12                     10.890
# 9      12.61    17.03          10.58        13.65                     13.785
#
#    Chandigarh  Delhi  Puducherry  All_India GDP
# ...

# %%
data11.isnull().sum(axis=1) #Check null values across rows
# Out:
# 7    0
# 8    0
# 9    0
# dtype: int64

# %%
data11
# Out:
#   Duration  Andhra Pradesh   Arunachal Pradesh  Assam  Bihar  Chhattisgarh  \
# 7  2013-14            12.85              16.38  13.31  12.30         16.44
# 8  2014-15            13.40              14.79  11.45  17.92         13.69
# 9  2015-16            15.85              12.07  13.19  10.59         10.98
#
#      Goa  Gujarat  Haryana  Himachal Pradesh      ...        Tamil Nadu  \
# 7  -5.77    11.47    15.45             14.42      ...             13.51
# 8  13.12    10.82     9.18             10.14      ...             12.51
# 9  10.75    11.09    10.91             12.28      ...             10.99
#
#    Telangana  Tripura  Uttar Pradesh  Uttarakhand  Andaman & Nicobar Islands  \
# 7      12.63    18.14          14.73        13.64                     16.680
# 8      13.05    15.92          10.51         8.12                     10.890
# 9      12.61    17.03          10.58        13.65                     13.785
#
#    Chandigarh  Delhi  Puducherry  All_India GDP
# ...

# %%
data11 = data11.rename(columns = {'Duration': 'State'}) #Rename the Duration column name to State
data11 = data11.set_index('State') # Set the State as index
data11 = data11.T #Transpose the data

# %%
data11['Avg Growth'] = data11.mean(axis=1) #find the average growth by mean function

# %%
data11 = data11.sort_values(by='Avg Growth', ascending=False) #Sort the data in descending manner

# %%
plt.figure(figsize=(14,8))
ax = sns.barplot(x='Avg Growth', y=data11.index, data=data11)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#Mizoram, Tripura, Nagaland, Manipur and Arunachal Pradesh are the five fast growing states
#Goa, Meghalaya, Odisha, Sikkim and Jammu & Kashmir are the bottom five states

# %%
home = (data11.loc[['Bihar','All_India GDP']]) #Extract home state and all India GDP
home
# Out:
# State          2013-14  2014-15  2015-16  Avg Growth
# Bihar            12.30    17.92    10.59   13.603333
# All_India GDP    12.97    10.65     9.99   11.203333

# %%
sns.barplot(x='Avg Growth', y=home.index, data=home)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#Bihar's GDP is higher than India's GDP

# %%
#Part-1-B

# %%
#Import the .csv files

# %%
Andhra = pd.read_csv('NAD-Andhra_Pradesh-GSVA_cur_2016-17.csv')
Arunachal = pd.read_csv('NAD-Arunachal_Pradesh-GSVA_cur_2015-16.csv')
Assam = pd.read_csv('NAD-Assam-GSVA_cur_2015-16.csv')
Bihar = pd.read_csv('NAD-Bihar-GSVA_cur_2015-16.csv')
Chhattisgarh = pd.read_csv("NAD-Chhattisgarh-GSVA_cur_2016-17.csv")
Goa = pd.read_csv('NAD-Goa-GSVA_cur_2015-16.csv')
Gujarat = pd.read_csv('NAD-Gujarat-GSVA_cur_2015-16.csv')
Haryana = pd.read_csv('NAD-Haryana-GSVA_cur_2016-17.csv')
Himachal = pd.read_csv('NAD-Himachal_Pradesh-GSVA_cur_2014-15.csv')
Jharkhand = pd.read_csv('NAD-Jharkhand-GSVA_cur_2015-16.csv')
Karnataka = pd.read_csv('NAD-Karnataka-GSVA_cur_2015-16.csv')
Kerala = pd.read_csv('NAD-Kerala-GSVA_cur_2015-16.csv')
Madhya = pd.read_csv("NAD-Madhya_Pradesh-GSVA_cur_2016-17.csv")
Maharashtra = pd.read_csv('NAD-Maharashtra-GSVA_cur_2014-15.csv')
Manipur = pd.read_csv('NAD-Manipur-GSVA_cur_2014-15.csv', encoding='unicode_escape')
Meghalaya = pd.read_csv('NAD-Meghalaya-GSVA_cur_2016-17.csv')
Mizoram = pd.read_csv('NAD-Mizoram-GSVA_cur_2014-15.csv')
Nagaland = pd.read_csv('NAD-Nagaland-GSVA_cur_2014-15.csv')
Odhisha = pd.read_csv('NAD-Odisha-GSVA_cur_2016-17.csv')
Punjab = pd.read_csv('NAD-Punjab-GSVA_cur_2014-15.csv')
Rajasthan = pd.read_csv('NAD-Rajasthan-GSVA_cur_2014-15.csv')
Sikkim = pd.read_csv('NAD-Sikkim-GSVA_cur_2015-16.csv')
Tamil = pd.read_csv('NAD-Tamil_Nadu-GSVA_cur_2016-17.csv')
Telangana = pd.read_csv('NAD-Telangana-GSVA_cur_2016-17.csv')
Tripura = pd.read_csv('NAD-Tripura-GSVA_cur_2014-15.csv')
UP = pd.read_csv('NAD-Uttar_Pradesh-GSVA_cur_2015-16.csv')
UK = pd.read_csv('NAD-Uttarakhand-GSVA_cur_2015-16.csv')

# %%
#Remove symbols like * and () from Item column

# %%
Andhra['Item'] = Andhra['Item'].map(lambda x: x.lstrip('*()').rstrip('*()'))
Arunachal['Item'] = Arunachal['Item'].map(lambda x: x.lstrip('*()').rstrip('*()'))
Assam['Item'] = Assam['Item'].map(lambda x: x.lstrip('*()').rstrip('*()'))
Bihar['Item'] = Bihar['Item'].map(lambda x: x.lstrip('*()').rstrip('*()'))
Chhattisgarh['Item'] = Chhattisgarh['Item'].map(lambda x: x.lstrip('*()').rstrip('*()'))
Goa['Item'] = Goa['Item'].map(lambda x: x.lstrip('*()').rstrip('*()'))
Gujarat['Item'] = Gujarat['Item'].map(lambda x: x.lstrip('*()').rstrip('*()'))
Haryana['Item'] = Haryana['Item'].map(lambda x: x.lstrip('*()').rstrip('*()'))
Himachal['Item'] = Himachal['Item'].map(lambda x: x.lstrip('*()').rstrip('*()'))
Jharkhand['Item'] = Jharkhand['Item'].map(lambda x: x.lstrip('*()').rstrip('*()'))
Karnataka['Item'] = Karnataka['Item'].map(lambda x: x.lstrip('*()').rstrip('*()'))
Kerala['Item'] = Kerala['Item'].map(lambda x: x.lstrip('*()').rstrip('*()'))
Madhya['Item'] = Madhya['Item'].map(lambda x: x.lstrip('*()').rstrip('*()'))
Maharashtra['Item'] = Maharashtra['Item'].map(lambda x: x.lstrip('*()').rstrip('*()'))
Manipur['Item'] = Manipur['Item'].map(lambda x: x.lstrip('*()').rstrip('*()'))
Meghalaya['Item'] = Meghalaya['Item'].map(lambda x: x.lstrip('*()').rstrip('*()'))
Mizoram['Item'] = Mizoram['Item'].map(lambda x: x.lstrip('*()').rstrip('*()'))
Nagaland['Item'] = Nagaland['Item'].map(lambda x: x.lstrip('*()').rstrip('*()'))
Odhisha['Item'] = Odhisha['Item'].map(lambda x: x.lstrip('*()').rstrip('*()'))
Punjab['Item'] = Punjab['Item'].map(lambda x: x.lstrip('*()').rstrip('*()'))
Rajasthan['Item'] = Rajasthan['Item'].map(lambda x: x.lstrip('*()').rstrip('*()'))
Sikkim['Item'] = Sikkim['Item'].map(lambda x: x.lstrip('*()').rstrip('*()'))
Tamil['Item'] = Tamil['Item'].map(lambda x: x.lstrip('*()').rstrip('*()'))
Telangana['Item'] = Telangana['Item'].map(lambda x: x.lstrip('*()').rstrip('*()'))
Tripura['Item'] = Tripura['Item'].map(lambda x: x.lstrip('*()').rstrip('*()'))
UP['Item'] = UP['Item'].map(lambda x: x.lstrip('*()').rstrip('*()'))
UK['Item'] = UK['Item'].map(lambda x: x.lstrip('*()').rstrip('*()'))

# %%
#Drop the not required columns and rename the 2014-15 Year with it's respective state name

# %%
Andhra = Andhra.drop(['S.No.','2011-12','2012-13','2013-14','2015-16','2016-17'], axis=1)
Andhra = Andhra.rename(columns={'2014-15':'Andhra Pradesh'})
Arunachal = Arunachal.drop(['S.No.','2011-12','2012-13','2013-14','2015-16'], axis=1)
Arunachal = Arunachal.rename(columns={'2014-15': 'Arunachal Pradesh'})
Assam = Assam.drop(['S.No.','2011-12','2012-13','2013-14','2015-16'], axis=1)
Assam = Assam.rename(columns={'2014-15': 'Assam'})
Bihar = Bihar.drop(['S.No.','2011-12','2012-13','2013-14','2015-16'], axis=1)
Bihar = Bihar.rename(columns={'2014-15': 'Bihar'})
Chhattisgarh = Chhattisgarh.drop(['S.No.','2011-12','2012-13','2013-14','2015-16','2016-17'], axis=1)
Chhattisgarh = Chhattisgarh.rename(columns={'2014-15': 'Chhattisgarh'})
Goa = Goa.drop(['S.No.','2011-12','2012-13','2013-14','2015-16'], axis=1)
Goa = Goa.rename(columns={'2014-15': 'Goa'})
Gujarat = Gujarat.drop(['S.No.','2011-12','2012-13','2013-14','2015-16'], axis=1)
Gujarat = Gujarat.rename(columns={'2014-15': 'Gujarat'})
Haryana = Haryana.drop(['S.No.','2011-12','2012-13','2013-14','2015-16','2016-17'], axis=1)
Haryana = Haryana.rename(columns={'2014-15': 'Haryana'})
Himachal = Himachal.drop(['S.No.','2011-12','2012-13','2013-14'], axis=1)
Himachal = Himachal.rename(columns={'2014-15': 'Himachal'})
Jharkhand = Jharkhand.drop(['S.No.','2011-12','2012-13','2013-14','2015-16'], axis=1)
Jharkhand = Jharkhand.rename(columns={'2014-15': 'Jharkhand'})
Karnataka = Karnataka.drop(['S.No.','2011-12','2012-13','2013-14','2015-16'], axis=1)
Karnataka = Karnataka.rename(columns={'2014-15': 'Karnataka'})
Kerala = Kerala.drop(['S.No.','2011-12','2012-13','2013-14','2015-16'], axis=1)
Kerala = Kerala.rename(columns={'2014-15': 'Kerala'})
Madhya = Madhya.drop(['S.No.','2011-12','2012-13','2013-14','2015-16','2016-17'], axis=1)
Madhya = Madhya.rename(columns={'2014-15': 'Madhya Pradesh'})
Maharashtra = Maharashtra.drop(['S.No.','2011-12','2012-13','2013-14'], axis=1)
Maharashtra = Maharashtra.rename(columns={'2014-15': 'Maharashtra'})

# %%
Manipur = Manipur.drop(['S.No.','2011-12','2012-13','2013-14'], axis=1)
Manipur = Manipur.rename(columns={'2014-15': 'Manipur'})
Meghalaya = Meghalaya.drop(['S.No.','2011-12','2012-13','2013-14','2015-16','2016-17'], axis=1)
Meghalaya = Meghalaya.rename(columns={'2014-15': 'Meghalaya'})
Mizoram = Mizoram.drop(['S.No.','2011-12','2012-13','2013-14'], axis=1)
Mizoram = Mizoram.rename(columns={'2014-15': 'Mizoram'})
Nagaland = Nagaland.drop(['S.No.','2011-12','2012-13','2013-14'], axis=1)
Nagaland = Nagaland.rename(columns={'2014-15': 'Nagaland'})
Odhisha = Odhisha.drop(['S.No.','2011-12','2012-13','2013-14','2015-16','2016-17'], axis=1)
Odhisha = Odhisha.rename(columns={'2014-15': 'Odhisha'})
Punjab = Punjab.drop(['S.No.','2011-12','2012-13','2013-14'], axis=1)
Punjab = Punjab.rename(columns={'2014-15': 'Punjab'})
Rajasthan = Rajasthan.drop(['S.No.','2011-12','2012-13','2013-14'], axis=1)
Rajasthan = Rajasthan.rename(columns={'2014-15': 'Rajasthan'})
Sikkim = Sikkim.drop(['S.No.','2011-12','2012-13','2013-14','2015-16'], axis=1)
Sikkim = Sikkim.rename(columns={'2014-15': 'Sikkim'})
Tamil = Tamil.drop(['S.No.','2011-12','2012-13','2013-14','2015-16','2016-17'], axis=1)
Tamil = Tamil.rename(columns={'2014-15': 'Tamil Nadu'})
Telangana = Telangana.drop(['S.No.','2011-12','2012-13','2013-14','2015-16','2016-17'], axis=1)
Telangana = Telangana.rename(columns={'2014-15': 'Telangana'})
Tripura = Tripura.drop(['S.No.','2011-12','2012-13','2013-14'], axis=1)
Tripura = Tripura.rename(columns={'2014-15': 'Tripura'})
UP = UP.drop(['S.No.','2011-12','2012-13','2013-14','2015-16'], axis=1)
UP = UP.rename(columns={'2014-15': 'Uttar Pradesh'})
UK = UK.drop(['S.No.','2011-12','2012-13','2013-14','2015-16'], axis=1)
UK = UK.rename(columns={'2014-15': 'Uttarakhand'})

# %%
#Collate the data in one single dataframe

# %%
collated = Andhra.merge(Arunachal, how='outer', on='Item')
collated = collated.merge(Assam, how='outer', on='Item')
collated = collated.merge(Bihar, how='outer', on='Item')
collated = collated.merge(Chhattisgarh, how='outer', on='Item')
collated = collated.merge(Goa, how='outer', on='Item')
collated = collated.merge(Gujarat, how='outer', on='Item')
collated = collated.merge(Haryana, how='outer', on='Item')
collated = collated.merge(Himachal, how='outer', on='Item')
collated = collated.merge(Jharkhand, how='outer', on='Item')
collated = collated.merge(Karnataka, how='outer', on='Item')
collated = collated.merge(Kerala, how='outer', on='Item')
collated = collated.merge(Madhya, how='outer', on='Item')
collated = collated.merge(Maharashtra, how='outer', on='Item')
collated = collated.merge(Manipur, how='outer', on='Item')
collated = collated.merge(Meghalaya, how='outer', on='Item')
collated = collated.merge(Mizoram, how='outer', on='Item')
collated = collated.merge(Nagaland, how='outer', on='Item')
collated = collated.merge(Odhisha, how='outer', on='Item')
collated = collated.merge(Punjab, how='outer', on='Item')
collated = collated.merge(Rajasthan, how='outer', on='Item')
collated = collated.merge(Sikkim, how='outer', on='Item')
collated = collated.merge(Tamil, how='outer', on='Item')
collated = collated.merge(Telangana, how='outer', on='Item')
collated = collated.merge(Tripura, how='outer', on='Item')
collated = collated.merge(UP, how='outer', on='Item')
collated = collated.merge(UK, how='outer', on='Item')

# %%
collated = collated.set_index("Item") #Set Item as index
collated = collated.T #Transpose the dataframe
merged = collated

# %%
collated = collated.sort_values(by='Per Capita GSDP (Rs.' , ascending=False) #Sort the dataframe in descending way for GDP

# %%
plt.figure(figsize=(14,8))
ax = sns.barplot(x='Per Capita GSDP (Rs.', y=collated.index, data=collated)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#Top 5 States: Goa, Sikkim, Haryana, Kerala and Uttarakhand
#Bottom 5 States: Bihar, Uttar Pradesh, Manipur, Assam and Jharkhand

# %%
collated
# Out:
# Item               Agriculture, forestry and fishing       Crops  Livestock  \
# Goa                                         308507.0    140421.0    30141.0
# Sikkim                                      137447.0    114976.0    17338.0
# Haryana                                    8015238.0   4636731.0  2916173.0
# Kerala                                     5930617.0   3070386.0  1656104.0
# Uttarakhand                                1601423.0    866146.0   391188.0
# Maharashtra                               16475655.0  10435121.0  3972829.0
# Himachal                                   1514981.0    853758.0   110304.0
# Tamil Nadu                                13064238.0   7297820.0  4693361.0
# Karnataka                                 11219422.0   8157179.0  1868771.0
# Gujarat                                   13769969.0   9671086.0  2698910.0
# Telangana                                  7591501.0   4162493.0  2951299.0
# ...

# %%
ratio = collated.iloc[0,32]/collated.iloc[26,32] #Ratio of highest per capita GDP to the lowest per capita GDP
ratio
# Out:
# 8.004741709371503

# %%
#Create new columns for percentage value of primary, secondary and tertiary against GSVA

# %%
collated['Primary Percentage'] = round(collated['Primary']/collated['TOTAL GSVA at basic prices']*100,2)
collated['Secondary Percentage'] = round(collated['Secondary']/collated['TOTAL GSVA at basic prices']*100,2)
collated['Tertiary Percentage'] = round(collated['Tertiary']/collated['TOTAL GSVA at basic prices']*100,2)
collated
# Out:
# Item               Agriculture, forestry and fishing       Crops  Livestock  \
# Goa                                         308507.0    140421.0    30141.0
# Sikkim                                      137447.0    114976.0    17338.0
# Haryana                                    8015238.0   4636731.0  2916173.0
# Kerala                                     5930617.0   3070386.0  1656104.0
# Uttarakhand                                1601423.0    866146.0   391188.0
# Maharashtra                               16475655.0  10435121.0  3972829.0
# Himachal                                   1514981.0    853758.0   110304.0
# Tamil Nadu                                13064238.0   7297820.0  4693361.0
# Karnataka                                 11219422.0   8157179.0  1868771.0
# Gujarat                                   13769969.0   9671086.0  2698910.0
# Telangana                                  7591501.0   4162493.0  2951299.0
# ...

# %%
percent = collated[['Primary Percentage','Secondary Percentage','Tertiary Percentage']] #Extracted data for plot
percent = percent.T
percent
# Out:
#                         Goa  Sikkim  Haryana  Kerala  Uttarakhand  \
# Item
# Primary Percentage     8.68    9.46    20.19   13.45        12.24
# Secondary Percentage  43.01   57.61    31.54   25.02        50.69
# Tertiary Percentage   48.31   32.93    48.27   61.52        37.06
#
#                       Maharashtra  Himachal  Tamil Nadu  Karnataka  Gujarat  \
# Item
# Primary Percentage          13.79     15.80       13.39      14.53    20.08
# Secondary Percentage        30.06     42.03       33.00      24.67    41.73
# Tertiary Percentage         56.15     42.17       53.60      60.80    38.19
#
#                       ...    Rajasthan  Tripura  Meghalaya  Odhisha  \
# Item                  ...
# Primary Percentage    ...        32.87    32.36      19.70    29.78
# Secondary Percentage  ...        22.40    16.64      27.86    29.71
# Tertiary Percentage   ...        44.73    51.00      52.44    40.51
#
#                       Madhya Pradesh  Jharkhand  Assam  Manipur  \
# Item
# ...

# %%
sns.set()
percent.T.plot(kind='bar', stacked=True)

# %%
collated['Category'] = pd.qcut(collated['Per Capita GSDP (Rs.'],q=[0.0,0.20,0.50,0.85,1],labels=['C4','C3','C2','C1'])

# %%
collated
# Out:
# Item               Agriculture, forestry and fishing       Crops  Livestock  \
# Goa                                         308507.0    140421.0    30141.0
# Sikkim                                      137447.0    114976.0    17338.0
# Haryana                                    8015238.0   4636731.0  2916173.0
# Kerala                                     5930617.0   3070386.0  1656104.0
# Uttarakhand                                1601423.0    866146.0   391188.0
# Maharashtra                               16475655.0  10435121.0  3972829.0
# Himachal                                   1514981.0    853758.0   110304.0
# Tamil Nadu                                13064238.0   7297820.0  4693361.0
# Karnataka                                 11219422.0   8157179.0  1868771.0
# Gujarat                                   13769969.0   9671086.0  2698910.0
# Telangana                                  7591501.0   4162493.0  2951299.0
# ...

# %%
grouped = collated.groupby('Category').sum().T/1000
grouped
# Out:
# Category                                                      C4  \
# Item
# Agriculture, forestry and fishing                    56735.04400
# Crops                                                39331.05500
# Livestock                                            11901.40500
# Forestry and logging                                  3673.62300
# Fishing and aquaculture                               1828.96000
# Mining and quarrying                                  6096.41900
# Primary                                              62831.46300
# Manufacturing                                        24987.03200
# Electricity, gas, water supply & other utility ...    4310.26400
# Construction                                         22775.94800
# Secondary                                            52073.24400
# Trade, repair, hotels and restaurants                27484.59500
# Trade & repair services                              25581.23900
# ...

# %%
g4 = grouped.drop(['C3','C2','C1'],axis=1)
g4 = g4.sort_values(by='C4', ascending=False)
g4['C4'] = g4['C4']/233252100*100
g4 = g4.drop(['Secondary','Gross State Domestic Product','TOTAL GSVA at basic prices','Tertiary','Primary','Per Capita GSDP (Rs.','Primary Percentage','Secondary Percentage','Tertiary Percentage'], axis=0)
g4 = g4.iloc[:5]
g3 = grouped.drop(['C4','C2','C1'],axis=1)
g3 = g3.sort_values(by='C3', ascending=False)
g3['C3'] = g3['C3']/177966400*100
g3 = g3.drop(['Secondary','Gross State Domestic Product','TOTAL GSVA at basic prices','Tertiary','Primary','Per Capita GSDP (Rs.','Primary Percentage','Secondary Percentage','Tertiary Percentage'], axis=0)
g3 = g3.iloc[:5]
g2 = grouped.drop(['C4','C3','C1'],axis=1)
g2 = g2.sort_values(by='C2', ascending=False)
g2['C2'] = g2['C2']/586380500*100
g2 = g2.drop(['Secondary','Gross State Domestic Product','TOTAL GSVA at basic prices','Tertiary','Primary','Per Capita GSDP (Rs.','Primary Percentage','Secondary Percentage','Tertiary Percentage'], axis=0)
g2 = g2.iloc[:5]
g1 = grouped.drop(['C3','C2','C4'],axis=1)
g1 = g1.sort_values(by='C1', ascending=False)
g1['C1'] = g1['C1']/101930700*100
g1 = g1.drop(['Secondary','Gross State Domestic Product','TOTAL GSVA at basic prices','Tertiary','Primary','Per Capita GSDP (Rs.','Primary Percentage','Secondary Percentage','Tertiary Percentage'], axis=0)
g1 = g1.iloc[:5]

# %%
sns.set()
g1.plot(kind='bar', stacked=True)
g2.plot(kind='bar', stacked=True)
g3.plot(kind='bar', stacked=True)
g4.plot(kind='bar', stacked=True)

# %%
#GDP is distributed uniformly in C1 category. However as we move towards C4 category, the data gets skewed.
#C1 even has better contribution from secondary and tertiary sectors which seems to increase the GDP.
#C1 depicts uniform consumerism across sectors.

# %%
#Sub sectors like Real estate, ownership of dwelling & professional services, Manufacturing and 
#Trade, repair, hotels and restaurants are related with high GDP

# %%
#Category C4 needs to focus on transport and services associated with it as well as mining, fishing & electricty
#Category C3 should focus on fishing & mining storage, hotels & restaurants, air & water transport, communication services 
# electricity in secondary sector
#Category C2 needs to focus on agriculture, crops, livestock, railways, water & air transport as well storage.
#Category C1 should also focus on agriculture, crops, mining, water & air transport, services incidental to transport
#storage and communication services.

# %%
#Overview of the data recommends that a high Population decreases per Capita GDP, even though GSDP is high. Hence C4 
#needs to plan for increasing awareness about family planning immediately and C2 should start this initiative too. 
#However C3 and C1 have a lower GDP per Caipta across sectors which they need to improve as their GSDP are the lowest
#They C1 has a huge requirement for educated and skilled labour.

# %%
#Part 2

# %%
data2 = pd.read_csv('Data2.csv') #Import the .csv file

# %%
data2
# Out:
#       Sl. No. Level of Education - State  Primary - 2012-2013  \
# 0           1              A & N Islands                 0.68
# 1           2             Andhra Pradesh                 3.18
# 2           3          Arunachal Pradesh                15.16
# 3           4                      Assam                 6.24
# 4           5                      Bihar                  NaN
# 5           6                 Chandigarh                  NaN
# 6           7                Chhatisgarh                 4.14
# 7           8       Dadra & Nagar Haveli                  NaN
# 8           9                Daman & Diu                  NaN
# 9          10                      Delhi                  NaN
# 10         11                        Goa                  NaN
# 11         12                    Gujarat                 0.74
# 12         13                    Haryana                 1.29
# 13         14           Himachal Pradesh                 0.45
# ...

# %%
#Drop not required columns

# %%
data2 = data2.drop(['Sl. No.','Primary - 2012-2013','Primary - 2014-2015.1','Upper Primary - 2012-2013','Upper Primary - 2013-2014','Secondary - 2012-2013','Secondary - 2013-2014','Senior Secondary - 2014-2015','Senior Secondary - 2012-2013','Senior Secondary - 2013-2014'], axis=1)

# %%
data2 = data2.rename(columns={'Level of Education - State':'State'}) #Renaming the column name
data2 = data2.set_index('State')
data2 = data2.T

data2
# Out:
# State                      A & N Islands  Andhra Pradesh  Arunachal Pradesh  \
# Primary - 2014-2015                 1.21            4.35              10.89
# Upper Primary - 2014-2015           1.69            5.20               6.71
# Secondary - 2014-2015               9.87           15.71              17.11
#
# State                      Assam  Bihar  Chandigarh  Chhatisgarh  \
# Primary - 2014-2015         7.44   2.09         NaN         1.42
# Upper Primary - 2014-2015  10.51   4.08        0.44         5.85
# Secondary - 2014-2015      27.06  25.90         NaN        21.26
#
# State                      Dadra & Nagar Haveli  Daman & Diu  Delhi  \
# Primary - 2014-2015                        1.57         0.85    NaN
# Upper Primary - 2014-2015                  4.02         3.11   0.76
# Secondary - 2014-2015                     16.77        32.27  11.81
#
# State                        ...      Punjab  Rajasthan  Sikkim  Tamil Nadu  \
# ...

# %%
#Drop unrequired columns post transposing the data

# %%
data2 = data2.drop(['A & N Islands','Chandigarh','Dadra & Nagar Haveli','Daman & Diu','West Bengal','Delhi','Jammu and Kashmir','Lakshadweep','Puducherry','All India'], axis=1)
data2 = data2.T

# %%
data2['GDP per capita'] = collated['Per Capita GSDP (Rs.'] #Extract the Per Capita GDP data and place in the part-2 dataset

# %%
data2
# Out:
#                    Primary - 2014-2015  Upper Primary - 2014-2015  \
# State
# Andhra Pradesh                    4.35                       5.20
# Arunachal Pradesh                10.89                       6.71
# Assam                             7.44                      10.51
# Bihar                             2.09                       4.08
# Chhatisgarh                       1.42                       5.85
# Goa                               0.20                       0.07
# Gujarat                           0.76                       6.41
# Haryana                           0.41                       5.81
# Himachal Pradesh                  0.46                       0.87
# Jharkhand                         6.41                       8.99
# Karnataka                         2.32                       3.85
# Kerala                             NaN                        NaN
# Madhya Pradesh                   10.14                       9.20
# ...

# %%
data2 = data2.reset_index()
data2
# Out:
#                 State  Primary - 2014-2015  Upper Primary - 2014-2015  \
# 0      Andhra Pradesh                 4.35                       5.20
# 1   Arunachal Pradesh                10.89                       6.71
# 2               Assam                 7.44                      10.51
# 3               Bihar                 2.09                       4.08
# 4         Chhatisgarh                 1.42                       5.85
# 5                 Goa                 0.20                       0.07
# 6             Gujarat                 0.76                       6.41
# 7             Haryana                 0.41                       5.81
# 8    Himachal Pradesh                 0.46                       0.87
# 9           Jharkhand                 6.41                       8.99
# 10          Karnataka                 2.32                       3.85
# 11             Kerala                  NaN                        NaN
# ...

# %%
cor = data2.corr()

# %%
# figure size
plt.figure(figsize=(10,8))

# heatmap
sns.heatmap(cor, cmap="YlGnBu", annot=True)
plt.show()

# %%
#Corelation is shown in the above heat map which clearly depicts that education drop outs decreases when GDP increases
